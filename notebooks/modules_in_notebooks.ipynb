# %%
from my_cool_package.logger.setup_logger import setup_logger
from my_cool_package.utils.test_module import test_logger

logger = setup_logger(log_file="logs/testing_from_notebook.log")
logger.info("This is a log message from the modules script.")
test_logger()
# Out:
# 2026-06-03 05:23:24 | INFO | __main__:<module>:5 - This is a log message from the modules script.
# 2026-06-03 05:23:24 | INFO | my_cool_package.logger.setup_logger:write:23 - Logging to file: /home/skall/git_good_guide/src/my_cool_package/utils/logs/run_log_20260603_052324.log
# 2026-06-03 05:23:24 | INFO | my_cool_package.utils.test_module:test_logger:6 - This is a log message from the test module.
